# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# load text
raw_text = load_doc('rhyme.txt')
print(raw_text)

# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)

# organize into sequences of characters
length = 10
sequences = list()
for i in range(length, len(raw_text)):
    # select sequence of tokens
    seq = raw_text[i-length:i+1]
    # store
    sequences.append(seq)
print('Total Sequences: %d' % len(sequences))

# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)
# Out:
# Sing a song of sixpence,
# A pocket full of rye.
# Four and twenty blackbirds,
# Baked in a pie.
#
# When the pie was opened
# The birds began to sing;
# Wasn't that a dainty dish,
# To set before the king.
#
# The king was in his counting house,
# Counting out his money;
# The queen was in the parlour,
# Eating bread and honey.
#
# The maid was in the garden,
# Hanging out the clothes,
# When down came a blackbird
# And pecked off her nose.
#
# Total Sequences: 399

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')

# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
    # integer encode line
    encoded_seq = [mapping[char] for char in line]
    # store
    sequences.append(encoded_seq)

# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)

# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)

# define model
model = Sequential()
model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, epochs=100, verbose=2)

# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))
# Out:
# Using TensorFlow backend.
# Vocabulary Size: 38
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 75)                34200
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
#  - 1s - loss: 3.6021 - accuracy: 0.1178
# Epoch 2/100
#  - 0s - loss: 3.4647 - accuracy: 0.2005
# Epoch 3/100
#  - 0s - loss: 3.1531 - accuracy: 0.1905
# Epoch 4/100
#  - 0s - loss: 3.0518 - accuracy: 0.1905
# Epoch 5/100
#  - 0s - loss: 3.0035 - accuracy: 0.1905
# Epoch 6/100
#  - 0s - loss: 2.9850 - accuracy: 0.1905
# Epoch 7/100
#  - 0s - loss: 2.9691 - accuracy: 0.1905
# Epoch 8/100
#  - 0s - loss: 2.9554 - accuracy: 0.1905
# Epoch 9/100
#  - 0s - loss: 2.9381 - accuracy: 0.1905
# Epoch 10/100
#  - 0s - loss: 2.9190 - accuracy: 0.1905
# Epoch 11/100
#  - 0s - loss: 2.9066 - accuracy: 0.1930
# Epoch 12/100
#  - 0s - loss: 2.8863 - accuracy: 0.1905
# Epoch 13/100
#  - 0s - loss: 2.8584 - accuracy: 0.1980
# Epoch 14/100
#  - 0s - loss: 2.8298 - accuracy: 0.2055
# Epoch 15/100
#  - 0s - loss: 2.8097 - accuracy: 0.2707
# Epoch 16/100
#  - 0s - loss: 2.7712 - accuracy: 0.2180
# Epoch 17/100
#  - 0s - loss: 2.7176 - accuracy: 0.2682
# Epoch 18/100
#  - 0s - loss: 2.6734 - accuracy: 0.2456
# Epoch 19/100
#  - 0s - loss: 2.6394 - accuracy: 0.2306
# Epoch 20/100
#  - 0s - loss: 2.6210 - accuracy: 0.2456
# Epoch 21/100
#  - 0s - loss: 2.5593 - accuracy: 0.2556
# Epoch 22/100
#  - 0s - loss: 2.5065 - accuracy: 0.2957
# Epoch 23/100
#  - 0s - loss: 2.4854 - accuracy: 0.3008
# Epoch 24/100
#  - 0s - loss: 2.4298 - accuracy: 0.2907
# Epoch 25/100
#  - 0s - loss: 2.3765 - accuracy: 0.3333
# Epoch 26/100
#  - 0s - loss: 2.3293 - accuracy: 0.3383
# Epoch 27/100
#  - 0s - loss: 2.3070 - accuracy: 0.3659
# Epoch 28/100
#  - 0s - loss: 2.2410 - accuracy: 0.3559
# Epoch 29/100
#  - 0s - loss: 2.1886 - accuracy: 0.3634
# Epoch 30/100
#  - 0s - loss: 2.1659 - accuracy: 0.3860
# Epoch 31/100
#  - 0s - loss: 2.1102 - accuracy: 0.4010
# Epoch 32/100
#  - 0s - loss: 2.0574 - accuracy: 0.4261
# Epoch 33/100
#  - 0s - loss: 2.0308 - accuracy: 0.4160
# Epoch 34/100
#  - 0s - loss: 1.9818 - accuracy: 0.4311
# Epoch 35/100
#  - 0s - loss: 1.9359 - accuracy: 0.4386
# Epoch 36/100
#  - 0s - loss: 1.8758 - accuracy: 0.4737
# Epoch 37/100
#  - 0s - loss: 1.8380 - accuracy: 0.4937
# Epoch 38/100
#  - 0s - loss: 1.8037 - accuracy: 0.5464
# Epoch 39/100
#  - 0s - loss: 1.7502 - accuracy: 0.5063
# Epoch 40/100
#  - 0s - loss: 1.7215 - accuracy: 0.5514
# Epoch 41/100
#  - 0s - loss: 1.6725 - accuracy: 0.5464
# Epoch 42/100
#  - 0s - loss: 1.6449 - accuracy: 0.5714
# Epoch 43/100
#  - 0s - loss: 1.5846 - accuracy: 0.5764
# Epoch 44/100
#  - 0s - loss: 1.5543 - accuracy: 0.5940
# Epoch 45/100
#  - 0s - loss: 1.5078 - accuracy: 0.6040
# Epoch 46/100
#  - 0s - loss: 1.4785 - accuracy: 0.6190
# Epoch 47/100
#  - 0s - loss: 1.4404 - accuracy: 0.6291
# Epoch 48/100
#  - 0s - loss: 1.3956 - accuracy: 0.6241
# Epoch 49/100
#  - 0s - loss: 1.3429 - accuracy: 0.6692
# Epoch 50/100
#  - 0s - loss: 1.3246 - accuracy: 0.6692
# Epoch 51/100
#  - 0s - loss: 1.2755 - accuracy: 0.6642
# Epoch 52/100
#  - 0s - loss: 1.2276 - accuracy: 0.7093
# Epoch 53/100
#  - 0s - loss: 1.2015 - accuracy: 0.7143
# Epoch 54/100
#  - 0s - loss: 1.1729 - accuracy: 0.6867
# Epoch 55/100
#  - 0s - loss: 1.1531 - accuracy: 0.7143
# Epoch 56/100
#  - 0s - loss: 1.1305 - accuracy: 0.7343
# Epoch 57/100
#  - 0s - loss: 1.0900 - accuracy: 0.7343
# Epoch 58/100
#  - 0s - loss: 1.0282 - accuracy: 0.7920
# Epoch 59/100
#  - 0s - loss: 0.9914 - accuracy: 0.7619
# Epoch 60/100
#  - 0s - loss: 0.9615 - accuracy: 0.8045
# Epoch 61/100
#  - 0s - loss: 0.9238 - accuracy: 0.8195
# Epoch 62/100
#  - 0s - loss: 0.8919 - accuracy: 0.8246
# Epoch 63/100
#  - 0s - loss: 0.8544 - accuracy: 0.8246
# Epoch 64/100
#  - 0s - loss: 0.8358 - accuracy: 0.8346
# Epoch 65/100
#  - 0s - loss: 0.8019 - accuracy: 0.8521
# Epoch 66/100
#  - 0s - loss: 0.7803 - accuracy: 0.8521
# Epoch 67/100
#  - 0s - loss: 0.7554 - accuracy: 0.8647
# Epoch 68/100
#  - 0s - loss: 0.7196 - accuracy: 0.8872
# Epoch 69/100
#  - 0s - loss: 0.6989 - accuracy: 0.8722
# Epoch 70/100
#  - 0s - loss: 0.6829 - accuracy: 0.8947
# Epoch 71/100
#  - 0s - loss: 0.6536 - accuracy: 0.8972
# Epoch 72/100
#  - 0s - loss: 0.6307 - accuracy: 0.9198
# Epoch 73/100
#  - 0s - loss: 0.6315 - accuracy: 0.9098
# Epoch 74/100
#  - 0s - loss: 0.5966 - accuracy: 0.9248
# Epoch 75/100
#  - 0s - loss: 0.5691 - accuracy: 0.9298
# Epoch 76/100
#  - 0s - loss: 0.5468 - accuracy: 0.9348
# Epoch 77/100
#  - 0s - loss: 0.5322 - accuracy: 0.9323
# Epoch 78/100
#  - 0s - loss: 0.4993 - accuracy: 0.9474
# Epoch 79/100
#  - 0s - loss: 0.4759 - accuracy: 0.9474
# Epoch 80/100
#  - 0s - loss: 0.4599 - accuracy: 0.9549
# Epoch 81/100
#  - 0s - loss: 0.4388 - accuracy: 0.9624
# Epoch 82/100
#  - 0s - loss: 0.4216 - accuracy: 0.9624
# Epoch 83/100
#  - 0s - loss: 0.4034 - accuracy: 0.9624
# Epoch 84/100
#  - 0s - loss: 0.3855 - accuracy: 0.9749
# Epoch 85/100
#  - 0s - loss: 0.3737 - accuracy: 0.9724
# Epoch 86/100
#  - 0s - loss: 0.3662 - accuracy: 0.9774
# Epoch 87/100
#  - 0s - loss: 0.3501 - accuracy: 0.9774
# Epoch 88/100
#  - 0s - loss: 0.3375 - accuracy: 0.9774
# Epoch 89/100
#  - 0s - loss: 0.3222 - accuracy: 0.9850
# Epoch 90/100
#  - 0s - loss: 0.3088 - accuracy: 0.9850
# Epoch 91/100
#  - 0s - loss: 0.3086 - accuracy: 0.9799
# Epoch 92/100
#  - 0s - loss: 0.2899 - accuracy: 0.9825
# Epoch 93/100
#  - 0s - loss: 0.2766 - accuracy: 0.9850
# Epoch 94/100
#  - 0s - loss: 0.2705 - accuracy: 0.9875
# Epoch 95/100
#  - 0s - loss: 0.2529 - accuracy: 0.9875
# Epoch 96/100
#  - 0s - loss: 0.2467 - accuracy: 0.9900
# Epoch 97/100
#  - 0s - loss: 0.2356 - accuracy: 0.9850
# Epoch 98/100
#  - 0s - loss: 0.2253 - accuracy: 0.9875
# Epoch 99/100
#  - 0s - loss: 0.2158 - accuracy: 0.9875
# Epoch 100/100
#  - 0s - loss: 0.2111 - accuracy: 0.9925

# %%
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
 
# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
    in_text = seed_text
    # generate a fixed number of characters
    for _ in range(n_chars):
        # encode the characters as integers
        encoded = [mapping[char] for char in in_text]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # one hot encode
        encoded = to_categorical(encoded, num_classes=len(mapping))
        #encoded = encoded.reshape(1, encoded.shape[0], encoded.shape[1])
        # predict character
        yhat = model.predict_classes(encoded, verbose=0)
        # reverse map integer to character
        out_char = ''
        for char, index in mapping.items():
            if index == yhat:
                out_char = char
                break
        # append to input
        in_text += char
    return in_text
 
# load the model
model = load_model('model.h5')
# load the mapping
mapping = load(open('mapping.pkl', 'rb'))
 
# test start of rhyme
print(generate_seq(model, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song of sixpence, A poc
# king was in his counting house
# hello worl The aab wwnddn aee
