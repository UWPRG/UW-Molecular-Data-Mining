# %%
## Download from web of science
## Using chemextractor to extract chemical names from the paper and count the occurrences

# %%
from chemdataextractor import Document
import pandas as pd
import os
from bs4 import BeautifulSoup
from chemdataextractor.doc import Document, Heading, Paragraph
from collections import Counter

# %%
chemical_list_fr = []
os.chdir('..')
for filename in os.listdir('./data/flame_retardants/'):
    if filename.endswith(".html"): 
        print(filename)
        f = open('./data/flame_retardants/'+filename,'rb')
        contents = f.read()
        soup = BeautifulSoup(contents)
        text = soup.get_text()
        doc = Document(
            Heading(text)
            )
        for i in range(len(doc.cems)):
            chemical_list_fr.append(str(doc.cems[i]))
# Out:
# savedrecs (6).html
# savedrecs (4).html
# savedrecs (2).html
# savedrecs (5).html
# savedrecs (7).html
# savedrecs (3).html
# savedrecs (14).html
# savedrecs (10).html
# savedrecs (12).html
# savedrecs (9).html
# savedrecs (13).html
# savedrecs (8).html
# savedrecs (11).html

# %%
chemical_list_fr
# Out:
# ['Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  ...]

# %%
counts = Counter(chemical_list_fr)
type(counts)
flame_retardant_list = pd.DataFrame.from_dict(counts, orient='index').sort_values(by = [0], ascending=False)
flame_retardant_list
# Out:
#                                                   0
# lithium                                          91
# PUA                                              91
# TPP                                              91
# PANI                                             91
# PZS-SrSn(OH)(6)                                  65
# AlOOH                                            52
# boron                                            39
# APTES                                            39
# phosphorus                                       39
# Li                                               39
# sulfur                                           39
# PBDEs                                            39
# PCBs                                             39
# silicon                                          26
# aryl                                             26
# H                                                26
# O                                                26
# polyurea                                         26
# SrSn(OH)(6)                                      26
# alpha-HCH                                        26
# polyamide                                        26
# epoxy resin                                      26
# organophosphorus                                 26
# TPHP                                             26
# 26040-51-7                                       13
# 35948-25-5                                       13
# polychlorinated biphenyls                        13
# P                                                13
# graphenes                                        13
# O\n\n\nAF                                        13
# ...                                              ..
# epoxy                                            13
# silica sol                                       13
# hydroxyl                                         13
# poly(urea-formaldehyde)                          13
# tris(2-butoxyethyl) phosphate                    13
# organochlorinated                                13
# triphenyl phosphate                              13
# polyphosphazene                                  13
# strontium hydroxystannate                        13
# phytic acid                                      13
# 68937-41-7                                       13
# -AlOOH                                           13
# DOPO                                             13
# Polybrominated diphenyl ethers                   13
# halogenated alkyl                                13
# 65652-41-7                                       13
# poly(acrylonitrile)                              13
# 29761-21-5                                       13
# 95906-11-9                                       13
# sulfonyldiphenol                                 13
# tris(1,3-dichloro-2-propyl) phosphate            13
# diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate  13
# EP                                               13
# TCIPP                                            13
# 21850-44-2                                       13
# 7-ethoxyresorufin                                13
# CO                                               13
# polyaniline                                      13
# Lithium                                          13
# gamma-HCH                                        13
#
# [94 rows x 1 columns]

# %%
flame_retardant_list.to_csv('./flame_retardant_count.csv')

# %%
chemical_list_ci = []
for filename in os.listdir('./data/corrosion_inhibitors/'):
    if filename.endswith(".html"): 
        print(filename)
        f = open('./data/corrosion_inhibitors/'+filename,'rb')
        contents = f.read()
        soup = BeautifulSoup(contents)
        text = soup.get_text()
        doc = Document(
            Heading(text)
            )
        for i in range(len(doc.cems)):
            chemical_list_ci.append(str(doc.cems[i]))
# Out:
# savedrecs (6).html
# savedrecs (4).html
# savedrecs (2).html
# savedrecs (5).html
# savedrecs (7).html
# savedrecs (3).html
# savedrecs (14).html
# savedrecs (10).html
# savedrecs (12).html
# savedrecs (9).html
# savedrecs (13).html
# savedrecs (8).html
# savedrecs (11).html

# %%
chemical_list_ci
# Out:
# ['Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TPHP',
#  'polychlorinated biphenyls',
#  'silica',
#  'polyurea',
#  'Suzanne\n   Jones',
#  'strontium',
#  'TPTP',
#  'Li',
#  'AlOOH',
#  'TPP',
#  'p-tert-butylphenyl diphenyl phosphate',
#  '19186-97-1',
#  'lithium',
#  'carbonyl',
#  'SrSn(OH)(6)',
#  'PUA',
#  'Sulfur',
#  'C13H20O2',
#  'phenol',
#  'O',
#  'PA66-5BL-B-d-APTES',
#  'PZS-SrSn(OH)(6)',
#  'Li',
#  'H',
#  'PUA',
#  'APTES',
#  'PANI',
#  'lithium',
#  'PUA',
#  'phosphorus',
#  'boron',
#  'graphene',
#  'alpha-HCH',
#  'phosphorus',
#  'C12H20O6',
#  'aryl',
#  'triethyl phosphate',
#  'PA66-5BL-APTES',
#  'PCBs',
#  '26040-51-7',
#  'hydrogen',
#  'epoxy resin',
#  'TPP',
#  '(3-Aminopropyl) triethoxysilane',
#  'H',
#  'Sr',
#  'Sn',
#  'gamma-HCH',
#  'Graphene',
#  'PBDEs',
#  'alpha-HCH',
#  'PCBs',
#  '68937-41-7',
#  'TPP',
#  'organophosphorus',
#  'PANI',
#  'AlOOH',
#  'boron',
#  'lithium',
#  'TPHP',
#  'polyamide',
#  'PBDEs',
#  'phytic acid',
#  'epoxy resin',
#  'strontium hydroxystannate',
#  'APTES',
#  'sulfur',
#  'polyphosphazene',
#  'triphenyl phosphate',
#  'polyamide',
#  'TPP',
#  'organochlorinated',
#  'tris(2-butoxyethyl) phosphate',
#  'poly(urea-formaldehyde)',
#  'hydroxyl',
#  'silica sol',
#  'epoxy',
#  'S\n   Jones',
#  'phosphorus',
#  '56803-37-3',
#  'LOl',
#  'lithium bis(fluorosulfonyl)imide',
#  '-AlOOH',
#  'PZS-SrSn(OH)(6)',
#  'DOPO',
#  'Li',
#  'Polybrominated diphenyl ethers',
#  'aryl',
#  'EP',
#  'TPP',
#  'Lithium',
#  'PZS-SrSn(OH)(6)',
#  'silicon',
#  'polyaniline',
#  'CO',
#  '7-ethoxyresorufin',
#  '21850-44-2',
#  'PZS-SrSn(OH)(6)',
#  'PANI',
#  'TCIPP',
#  'O',
#  'lithium',
#  'diethyl [2-(1, 3-dioxolan-2-yl) ethyl] malonate',
#  'polyurea',
#  'sulfur',
#  'halogenated alkyl',
#  'PANI',
#  'tris(1,3-dichloro-2-propyl) phosphate',
#  'APTES',
#  'sulfonyldiphenol',
#  '95906-11-9',
#  'AlOOH',
#  'AlOOH',
#  '29761-21-5',
#  'lithium',
#  'poly(acrylonitrile)',
#  '65652-41-7',
#  '25713-60-4',
#  'SrSn(OH)(6)',
#  'PANI',
#  '.fr_address_row2',
#  'TDCIPP',
#  'silicon',
#  'TPP',
#  'BPDP',
#  'boron',
#  'PUA',
#  '1,1,2,2-tetrafluoroethyl-2,2,3,3-tetrafluoropropyl',
#  'sulfur',
#  '4-(benzyloxy) cyclohexanone',
#  'organophosphorus',
#  'PUA',
#  'alkyl',
#  'PCBs',
#  'lithium',
#  'PANI',
#  'Polyaniline',
#  'lithium',
#  'HENRI\xa0L-5500-2015\xa0\n\n\n\n\n\nOI\n\n\n\nVAHABI',
#  'PUA',
#  'DDE',
#  '35948-25-5',
#  'PBDEs',
#  'O\n\n\nAF',
#  'graphenes',
#  'P',
#  'TPP',
#  'PUA',
#  ...]

# %%
counts = Counter(chemical_list_ci)
corrosion_inhibitor_list = pd.DataFrame.from_dict(counts, orient='index').sort_values(by = [0], ascending=False)
corrosion_inhibitor_list.to_csv('./corrosion_inhibitor_list.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-b5872261ae4c> in <module>
# ----> 1 counts = Counter(chemical_list_ci)
#       2 corrosion_inhibitor_list = pd.DataFrame.from_dict(counts, orient='index').sort_values(by = [0], ascending=False)
#       3 #corrosion_inhibitor_list.to_csv('./corrosion_inhibitor_list.csv')
#       4
#       5
#
# NameError: name 'Counter' is not defined
