# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# load text
raw_text = load_doc('rhyme.txt')
print(raw_text)

# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)

# organize into sequences of characters
length = 10
sequences = list()
for i in range(length, len(raw_text)):
    # select sequence of tokens
    seq = raw_text[i-length:i+1]
    # store
    sequences.append(seq)
print('Total Sequences: %d' % len(sequences))

# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)
# Out:
# Sing a song of sixpence,
# A pocket full of rye.
# Four and twenty blackbirds,
# Baked in a pie.
#
# When the pie was opened
# The birds began to sing;
# Wasn't that a dainty dish,
# To set before the king.
#
# The king was in his counting house,
# Counting out his money;
# The queen was in the parlour,
# Eating bread and honey.
#
# The maid was in the garden,
# Hanging out the clothes,
# When down came a blackbird
# And pecked off her nose.
#
# Total Sequences: 399

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import Flatten

# load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')

# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
    # integer encode line
    encoded_seq = [mapping[char] for char in line]
    # store
    sequences.append(encoded_seq)

# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
# Out:
# Using TensorFlow backend.
# Vocabulary Size: 38

# %%
# define model
model = Sequential()
model.add(Bidirectional(LSTM(75, return_sequences='True'), input_shape=(X.shape[1], X.shape[2])))
model.add(Flatten())
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, epochs=100, verbose=2)

# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 10, 150)           68400
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1500)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 38)                57038
# =================================================================
# Total params: 125,438
# Trainable params: 125,438
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
#  - 3s - loss: 3.5345 - accuracy: 0.1203
# Epoch 2/100
#  - 0s - loss: 3.0894 - accuracy: 0.1905
# Epoch 3/100
#  - 0s - loss: 3.0142 - accuracy: 0.1905
# Epoch 4/100
#  - 0s - loss: 2.9256 - accuracy: 0.1905
# Epoch 5/100
#  - 0s - loss: 2.8729 - accuracy: 0.1905
# Epoch 6/100
#  - 0s - loss: 2.8126 - accuracy: 0.1905
# Epoch 7/100
#  - 0s - loss: 2.7300 - accuracy: 0.1930
# Epoch 8/100
#  - 0s - loss: 2.6277 - accuracy: 0.2406
# Epoch 9/100
#  - 0s - loss: 2.4585 - accuracy: 0.2481
# Epoch 10/100
#  - 0s - loss: 2.2706 - accuracy: 0.3459
# Epoch 11/100
#  - 0s - loss: 2.0488 - accuracy: 0.3759
# Epoch 12/100
#  - 0s - loss: 1.8584 - accuracy: 0.4561
# Epoch 13/100
#  - 0s - loss: 1.7269 - accuracy: 0.4912
# Epoch 14/100
#  - 0s - loss: 1.5572 - accuracy: 0.4987
# Epoch 15/100
#  - 0s - loss: 1.4296 - accuracy: 0.5840
# Epoch 16/100
#  - 0s - loss: 1.2944 - accuracy: 0.6140
# Epoch 17/100
#  - 0s - loss: 1.2005 - accuracy: 0.6642
# Epoch 18/100
#  - 0s - loss: 1.1349 - accuracy: 0.6416
# Epoch 19/100
#  - 0s - loss: 1.0107 - accuracy: 0.6967
# Epoch 20/100
#  - 0s - loss: 0.9097 - accuracy: 0.7193
# Epoch 21/100
#  - 0s - loss: 0.8054 - accuracy: 0.7594
# Epoch 22/100
#  - 0s - loss: 0.7776 - accuracy: 0.7619
# Epoch 23/100
#  - 0s - loss: 0.6943 - accuracy: 0.8246
# Epoch 24/100
#  - 0s - loss: 0.6261 - accuracy: 0.8396
# Epoch 25/100
#  - 0s - loss: 0.5762 - accuracy: 0.8496
# Epoch 26/100
#  - 0s - loss: 0.4783 - accuracy: 0.8897
# Epoch 27/100
#  - 0s - loss: 0.4125 - accuracy: 0.9273
# Epoch 28/100
#  - 0s - loss: 0.3870 - accuracy: 0.9348
# Epoch 29/100
#  - 0s - loss: 0.3372 - accuracy: 0.9248
# Epoch 30/100
#  - 0s - loss: 0.2916 - accuracy: 0.9549
# Epoch 31/100
#  - 0s - loss: 0.2686 - accuracy: 0.9624
# Epoch 32/100
#  - 0s - loss: 0.2188 - accuracy: 0.9649
# Epoch 33/100
#  - 0s - loss: 0.1952 - accuracy: 0.9850
# Epoch 34/100
#  - 0s - loss: 0.1694 - accuracy: 0.9850
# Epoch 35/100
#  - 0s - loss: 0.1607 - accuracy: 0.9799
# Epoch 36/100
#  - 0s - loss: 0.1397 - accuracy: 0.9925
# Epoch 37/100
#  - 0s - loss: 0.1315 - accuracy: 0.9950
# Epoch 38/100
#  - 0s - loss: 0.1137 - accuracy: 0.9950
# Epoch 39/100
#  - 0s - loss: 0.1019 - accuracy: 0.9900
# Epoch 40/100
#  - 0s - loss: 0.1009 - accuracy: 0.9900
# Epoch 41/100
#  - 0s - loss: 0.0852 - accuracy: 0.9950
# Epoch 42/100
#  - 0s - loss: 0.0768 - accuracy: 0.9950
# Epoch 43/100
#  - 0s - loss: 0.0813 - accuracy: 0.9925
# Epoch 44/100
#  - 0s - loss: 0.0673 - accuracy: 0.9950
# Epoch 45/100
#  - 0s - loss: 0.0663 - accuracy: 0.9950
# Epoch 46/100
#  - 0s - loss: 0.0588 - accuracy: 0.9950
# Epoch 47/100
#  - 0s - loss: 0.0609 - accuracy: 0.9900
# Epoch 48/100
#  - 0s - loss: 0.0514 - accuracy: 0.9925
# Epoch 49/100
#  - 0s - loss: 0.0458 - accuracy: 0.9950
# Epoch 50/100
#  - 0s - loss: 0.0588 - accuracy: 0.9950
# Epoch 51/100
#  - 0s - loss: 0.0450 - accuracy: 0.9950
# Epoch 52/100
#  - 0s - loss: 0.0415 - accuracy: 0.9950
# Epoch 53/100
#  - 0s - loss: 0.0396 - accuracy: 0.9925
# Epoch 54/100
#  - 0s - loss: 0.0366 - accuracy: 0.9925
# Epoch 55/100
#  - 0s - loss: 0.0358 - accuracy: 0.9950
# Epoch 56/100
#  - 0s - loss: 0.0368 - accuracy: 0.9950
# Epoch 57/100
#  - 0s - loss: 0.0332 - accuracy: 0.9975
# Epoch 58/100
#  - 0s - loss: 0.0405 - accuracy: 0.9950
# Epoch 59/100
#  - 0s - loss: 0.0416 - accuracy: 0.9900
# Epoch 60/100
#  - 0s - loss: 0.0319 - accuracy: 0.9925
# Epoch 61/100
#  - 0s - loss: 0.0338 - accuracy: 0.9900
# Epoch 62/100
#  - 0s - loss: 0.0377 - accuracy: 0.9975
# Epoch 63/100
#  - 0s - loss: 0.0316 - accuracy: 0.9950
# Epoch 64/100
#  - 0s - loss: 0.0331 - accuracy: 0.9900
# Epoch 65/100
#  - 0s - loss: 0.0261 - accuracy: 0.9925
# Epoch 66/100
#  - 0s - loss: 0.0273 - accuracy: 0.9950
# Epoch 67/100
#  - 0s - loss: 0.0295 - accuracy: 0.9950
# Epoch 68/100
#  - 0s - loss: 0.0249 - accuracy: 0.9925
# Epoch 69/100
#  - 0s - loss: 0.0234 - accuracy: 0.9925
# Epoch 70/100
#  - 0s - loss: 0.0268 - accuracy: 0.9950
# Epoch 71/100
#  - 0s - loss: 0.0225 - accuracy: 0.9925
# Epoch 72/100
#  - 0s - loss: 0.0249 - accuracy: 0.9925
# Epoch 73/100
#  - 0s - loss: 0.0216 - accuracy: 0.9925
# Epoch 74/100
#  - 0s - loss: 0.0225 - accuracy: 0.9925
# Epoch 75/100
#  - 0s - loss: 0.0250 - accuracy: 0.9950
# Epoch 76/100
#  - 0s - loss: 0.0277 - accuracy: 0.9925
# Epoch 77/100
#  - 0s - loss: 0.0289 - accuracy: 0.9925
# Epoch 78/100
#  - 0s - loss: 0.0213 - accuracy: 0.9950
# Epoch 79/100
#  - 0s - loss: 0.0231 - accuracy: 0.9950
# Epoch 80/100
#  - 0s - loss: 0.0203 - accuracy: 0.9950
# Epoch 81/100
#  - 0s - loss: 0.0193 - accuracy: 0.9950
# Epoch 82/100
#  - 0s - loss: 0.0217 - accuracy: 0.9925
# Epoch 83/100
#  - 0s - loss: 0.0191 - accuracy: 0.9950
# Epoch 84/100
#  - 0s - loss: 0.0197 - accuracy: 0.9950
# Epoch 85/100
#  - 0s - loss: 0.0179 - accuracy: 0.9925
# Epoch 86/100
#  - 0s - loss: 0.0167 - accuracy: 0.9900
# Epoch 87/100
#  - 0s - loss: 0.0164 - accuracy: 0.9950
# Epoch 88/100
#  - 0s - loss: 0.0245 - accuracy: 0.9925
# Epoch 89/100
#  - 0s - loss: 0.0164 - accuracy: 0.9925
# Epoch 90/100
#  - 0s - loss: 0.0193 - accuracy: 0.9950
# Epoch 91/100
#  - 0s - loss: 0.0168 - accuracy: 0.9925
# Epoch 92/100
#  - 0s - loss: 0.0192 - accuracy: 0.9925
# Epoch 93/100
#  - 0s - loss: 0.0213 - accuracy: 0.9925
# Epoch 94/100
#  - 0s - loss: 0.0170 - accuracy: 0.9925
# Epoch 95/100
#  - 0s - loss: 0.0173 - accuracy: 0.9950
# Epoch 96/100
#  - 0s - loss: 0.0156 - accuracy: 0.9950
# Epoch 97/100
#  - 0s - loss: 0.0221 - accuracy: 0.9950
# Epoch 98/100
#  - 0s - loss: 0.0178 - accuracy: 0.9950
# Epoch 99/100
#  - 0s - loss: 0.0196 - accuracy: 0.9925
# Epoch 100/100
#  - 0s - loss: 0.0162 - accuracy: 0.9900

# %%
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
 
# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
    in_text = seed_text
    # generate a fixed number of characters
    for _ in range(n_chars):
        # encode the characters as integers
        encoded = [mapping[char] for char in in_text]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # one hot encode
        encoded = to_categorical(encoded, num_classes=len(mapping))
        #encoded = encoded.reshape(1, encoded.shape[0], encoded.shape[1])
        # predict character
        yhat = model.predict_classes(encoded, verbose=0)
        # reverse map integer to character
        out_char = ''
        for char, index in mapping.items():
            if index == yhat:
                out_char = char
                break
        # append to input
        in_text += char
    return in_text
 
# load the model
model = load_model('model.h5')
# load the mapping
mapping = load(open('mapping.pkl', 'rb'))
 
# test start of rhyme
print(generate_seq(model, mapping, 10, 'A black ho', 20))
# test mid-line
#print(generate_seq(model, mapping, 10, 'gravitatio', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello worl', 20))
# Out:
# A black hore, A paeng blout th
# hello worlixpee And poeng Tue
